# %%
import folium
import pandas

data = pandas.read_csv("Volcanoes.txt")
lat = list(data["LAT"])
lon = list(data["LON"])
elev = list(data["ELEV"])

def color_producer(elevation):
    if elevation < 1000:
        return 'green'
    elif 1000 <= elevation < 3000:
        return 'orange'
    else:
        return 'red'

map = folium.Map(location=[38.58, -99.09], zoom_start=6, tiles="Stamen Terrain")

fg = folium.FeatureGroup(name="My Map")

for lt, ln, el in zip(lat, lon, elev):
    fg.add_child(folium.Marker(location=[lt, ln], popup=str(el)+" m", icon=folium.Icon(color=color_producer(el))))
    
map.add_child(fg)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e98964f81d340bde7019e4d0c8ca8405 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e98964f81d340bde7019e4d0c8ca8405&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e98964f81d340bde7019e4d0c8ca8405 = L.map(
#                 &quot;map_e98964f81d340bde7019e4d0c8ca8405&quot;,
#                 {
#                     center: [38.58, -99.09],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d08666645828376f9abff646f3e5f812 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e98964f81d340bde7019e4d0c8ca8405);
#
#
#             var feature_group_5641bf96e7c5c3fda6c599094182250a = L.featureGroup(
#                 {}
#             ).addTo(map_e98964f81d340bde7019e4d0c8ca8405);
#
#
#             var marker_e0295cdddd2c87d856966e332b8930f2 = L.marker(
#                 [48.7767982, -121.810997],
#                 {}
#             ).addTo(feature_group_5641bf96e7c5c3fda6c599094182250a);
#
#
#             var icon_a0ef96b56f2a5de333eb5660e666466a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e0295cdddd2c87d856966e332b8930f2.setIcon(icon_a0ef96b56f2a5de333eb5660e666466a);
#
#
#         var popup_fd659fabb20a3fd5d3ff91ff45d1c76a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f6862acca8ed635d4b983271d7c75704 = $(`&lt;div id=&quot;html_f6862acca8ed635d4b983271d7c75704&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3285.0 m&lt;/div&gt;`)[0];
#             popup_fd659fabb20a3fd5d3ff91ff45d1c76a.setContent(html_f6862acca8ed635d4b983271d7c75704);
#
#
#         marker_e0295cdddd2c87d856966e332b8930f2.bindPopup(popup_fd659fabb20a3fd5d3ff91ff45d1c76a)
#         ;
#
#
#
#
#             var marker_cc6d32d2c0966305248bc57dc70f86b7 = L.marker(
#                 [48.1118011, -121.1110001],
#                 {}
#             ).addTo(feature_group_5641bf96e7c5c3fda6c599094182250a);
#
#
#             var icon_5e8c40f54d4892378afb1ca8cbca9f0c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cc6d32d2c0966305248bc57dc70f86b7.setIcon(icon_5e8c40f54d4892378afb1ca8cbca9f0c);
#
#
#         var popup_305d6753deebaf6063d2a9a1322f6cee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2f095978ba958781108482a69bdad754 = $(`&lt;div id=&quot;html_2f095978ba958781108482a69bdad754&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3213.0 m&lt;/div&gt;`)[0];
#             popup_305d6753deebaf6063d2a9a1322f6cee.setContent(html_2f095978ba958781108482a69bdad754);
#
#
#         marker_cc6d32d2c0966305248bc57dc70f86b7.bindPopup(popup_305d6753deebaf6063d2a9a1322f6cee)
#         ;
#
#
#
#
#             var marker_9132128d0df7d1e70a451a974550bce5 = L.marker(
#                 [46.8698006, -121.7509995],
#                 {}
#             ).addTo(feature_group_5641bf96e7c5c3fda6c599094182250a);
#
#
#             var icon_4e28960c25062f542e49dbffc8eaaa7b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9132128d0df7d1e70a451a974550bce5.setIcon(icon_4e28960c25062f542e49dbffc8eaaa7b);
#
#
#         var popup_9108d4266cb8c91289c8b94f632501f9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1981bb686bd0c412895468e6e335bf14 = $(`&lt;div id=&quot;html_1981bb686bd0c412895468e6e335bf14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4392.0 m&lt;/div&gt;`)[0];
#             popup_9108d4266cb8c91289c8b94f632501f9.setContent(html_1981bb686bd0c412895468e6e335bf14);
#
#
#         marker_9132128d0df7d1e70a451a974550bce5.bindPopup(popup_9108d4266cb8c91289c8b94f632501f9)
#         ;
#
#
#
#
#             var marker_26e3a7156b360acc9ba63acdfcf05f57 = L.marker(
#                 [46.1997986, -122.1809998],
#                 {}
#             ).addTo(feature_group_5641bf96e7c5c3fda6c599094182250a);

# %%
import pandas
data = pandas.read_csv("Volcanoes.txt")
data
# Out:
#     VOLCANX020    NUMBER            NAME       LOCATION  \
# 0        509.0  1201-01=           Baker  US-Washington
# 1        511.0  1201-02-    Glacier Peak  US-Washington
# 2        513.0  1201-03-         Rainier  US-Washington
# 3        515.0  1201-05-      St. Helens  US-Washington
# 4        516.0  1201-04-           Adams  US-Washington
# ..         ...       ...             ...            ...
# 57       580.0  1210-03-  Valles Caldera  US-New Mexico
# 58       581.0  1209-02-   Sunset Crater     US-Arizona
# 59       584.0  1203-20-           Amboy  US-California
# 60       586.0  1210-02-    Zuni-Bandera  US-New Mexico
# 61       588.0  1210-01-       Carrizozo  US-New Mexico
#
#                    STATUS    ELEV             TYPE TIMEFRAME        LAT  \
# 0              Historical  3285.0  Stratovolcanoes        D3  48.776798
# 1        Tephrochronology  3213.0    Stratovolcano        D4  48.111801
# 2        Dendrochronology  4392.0    Stratovolcano        D3  46.869801
# 3              Historical  2549.0    Stratovolcano        D1  46.199799
# 4        Tephrochronology  3742.0    Stratovolcano        D6  46.205799
# ..                    ...     ...              ...       ...        ...
# 57  Pleistocene-Fumarolic  3430.0          Caldera         Q  35.869999
# 58       Dendrochronology  2447.0      Cinder cone        D6  35.369999
# 59               Holocene   288.0      Cinder cone         U  34.549999
# 60           Anthropology  2550.0   Volcanic field        D7  34.799999
# 61               Holocene  1731.0      Cinder cone         U  33.780102
#
#            LON
# 0  -121.810997
# 1  -121.111000
# 2  -121.751000
# 3  -122.181000
# 4  -121.490997
# ..         ...
# 57 -106.570999
# 58 -111.501000
# 59 -115.780998
# 60 -108.001000
# 61 -105.931000
#
# [62 rows x 10 columns]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.columns
# Out:
# Index(['VOLCANX020', 'NUMBER', 'NAME', 'LOCATION', 'STATUS', 'ELEV', 'TYPE',
#        'TIMEFRAME', 'LAT', 'LON'],
#       dtype='object')

# %%
list(data["LON"])
# Out:
# [-121.810997,
#  -121.1110001,
#  -121.7509995,
#  -122.1809998,
#  -121.4909973,
#  -122.0810013,
#  -121.8209991,
#  -121.6910019,
#  -121.8010025,
#  -121.7710037,
#  -121.9309998,
#  -121.8310013,
#  -121.8410034,
#  -121.7710037,
#  -121.7710037,
#  -121.6809998,
#  -121.2210007,
#  -121.8209991,
#  -120.8610001,
#  -122.1009979,
#  -120.7509995,
#  -120.6610031,
#  -122.1210022,
#  -110.6709976,
#  -118.7509995,
#  -117.4710007,
#  -117.8010025,
#  -113.5009995,
#  -112.4509964,
#  -114.3509979,
#  -117.5810013,
#  -121.5709991,
#  -113.2210007,
#  -122.2009964,
#  -121.4410019,
#  -121.3610001,
#  -121.6009979,
#  -121.5510025,
#  -120.8310013,
#  -121.5009995,
#  -122.7710037,
#  -119.7210007,
#  -107.0309982,
#  -119.0309982,
#  -112.5009995,
#  -119.0009995,
#  -119.0210037,
#  -118.8710022,
#  -119.0510025,
#  -117.4509964,
#  -112.6709976,
#  -113.6210022,
#  -112.401001,
#  -118.3209991,
#  -117.8209991,
#  -113.1309967,
#  -116.6210022,
#  -106.5709991,
#  -111.5009995,
#  -115.7809982,
#  -108.0009995,
#  -105.9309998]
