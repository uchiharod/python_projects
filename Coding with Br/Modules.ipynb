# %%
#module - a file containing python code. May contain functions, classes, etc.
#Used with modular programming, which is to separate a program into parts
#import messages
#import messages as m
#from messages import helloabye
#from messages import * (this one is dangerous)

help("modules")
# Out:
# Please wait a moment while I gather a list of all available modules...
# C:\Users\graph\anaconda3\lib\site-packages\IPython\kernel\__init__.py:12: ShimWarning: The `IPython.kernel` package has been deprecated since IPython 4.0.You should import from ipykernel or jupyter_client instead.
#   warn("The `IPython.kernel` package has been deprecated since IPython 4.0."
# WARNING: AstropyDeprecationWarning: The private astropy._erfa module has been made into its own package, pyerfa, which is a dependency of astropy and can be imported directly using "import erfa" [astropy._erfa]
# C:\Users\graph\anaconda3\lib\pkgutil.py:92: MatplotlibDeprecationWarning:
# The matplotlib.compat module was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   __import__(info.name)
# C:\Users\graph\anaconda3\lib\site-packages\nltk\twitter\__init__.py:21: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn(
# C:\Users\graph\anaconda3\lib\site-packages\skimage\viewer\utils\__init__.py:1: UserWarning: Recommended matplotlib backend is `Agg` for full skimage.viewer functionality.
#   from .core import *
# Update LANGUAGE_CODES (inside config/base.py) if a new translation has been added to Spyder
# C:\Users\graph\anaconda3\lib\site-packages\qtawesome\iconic_font.py:313: UserWarning: You need to have a running QApplication to use QtAwesome!
#   warnings.warn("You need to have a running "
# C:\Users\graph\anaconda3\lib\pkgutil.py:107: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
#   yield from walk_packages(path, info.name+'.', onerror)
# Cython              brain_responses     lxml                smtplib
# IPython             brain_scipy_signal  lzma                sndhdr
# OpenSSL             brain_six           mailbox             sniffio
# PIL                 brain_sqlalchemy    mailcap             snowballstemmer
# PyQt5               brain_ssl           markupsafe          socket
# __future__          brain_subprocess    marshal             socketserver
# _abc                brain_threading     math                socks
# _ast                brain_type          matplotlib          sockshandler
# _asyncio            brain_typing        mccabe              sortedcollections
# _bisect             brain_uuid          menuinst            sortedcontainers
# _black_version      branca              mimetypes           soupsieve
# _blake2             brotli              mistune             sphinx
# _bootlocale         bs4                 mkl                 sphinxcontrib
# _bz2                builtins            mkl_fft             spyder
# _cffi_backend       bz2                 mkl_random          spyder_kernels
# _codecs             cProfile            mmap                sqlalchemy
# _codecs_cn          calendar            mmapfile            sqlite3
# _codecs_hk          certifi             mmsystem            sre_compile
# _codecs_iso2022     cffi                mock                sre_constants
# _codecs_jp          cgi                 modulefinder        sre_parse
# _codecs_kr          cgitb               more_itertools      ssl
# _codecs_tw          chardet             mpmath              sspi
# _collections        chunk               msgpack             sspicon
# _collections_abc    click               msilib              stat
# _compat_pickle      cloudpickle         msvcrt              statistics
# _compression        clyent              multipledispatch    statsmodels
# _contextvars        cmath               multiprocessing     storemagic
# _csv                cmd                 mypy_extensions     string
# _ctypes             code                nacl                stringprep
# _ctypes_test        codecs              navigator_updater   struct
# _datetime           codeop              nbclassic           subprocess
# _decimal            collections         nbclient            sunau
# _distutils_hack     colorama            nbconvert           symbol
# _dummy_thread       colorsys            nbformat            sympy
# _elementtree        commctrl            nest_asyncio        sympyprinting
# _functools          compileall          netbios             symtable
# _hashlib            comtypes            netrc               sys
# _heapq              concurrent          networkx            sysconfig
# _imp                conda               nltk                tables
# _io                 conda_build         nntplib             tabnanny
# _json               conda_content_trust nose                tarfile
# _locale             conda_env           notebook            tblib
# _lsprof             conda_package_handling nt                  telnetlib
# _lzma               conda_token         ntpath              tempfile
# _markupbase         conda_verify        ntsecuritycon       terminado
# _md5                configparser        nturl2path          test
# _msi                contextlib          numba               test_data
# _multibytecodec     contextlib2         numbers             test_pycosat
# _multiprocessing    contextvars         numexpr             testpath
# _nsis               copy                numpy               tests
# _opcode             copyreg             numpydoc            textdistance
# _operator           crypt               odbc                textwrap
# _osx_support        cryptography        olefile             this
# _overlapped         csv                 opcode              threading
# _pickle             ctypes              openpyxl            threadpoolctl
# _py_abc             curl                operator            three_merge
# _pydecimal          curses              optparse            tifffile
# _pyio               cwp                 os                  time
# _pyrsistent_version cycler              packaging           timeit
# _pytest             cython              pandas              timer
# _queue              cythonmagic         pandocfilters       tkinter
# _random             cytoolz             paramiko            tlz
# _sha1               dask                parser              token
# _sha256             dataclasses         parso               tokenize
# _sha3               datetime            partd               toml
# _sha512             dateutil            past                toolz
# _signal             dbi                 path                tornado
# _sitebuiltins       dbm                 pathlib             tqdm
# _socket             dde                 pathlib2            trace
# _sqlite3            decimal             pathspec            traceback
# _sre                decorator           patsy               tracemalloc
# _ssl                defusedxml          pdb                 traitlets
# _stat               diff_match_patch    pep8                tty
# _statistics         difflib             perfmon             turtle
# _string             dis                 pexpect             turtledemo
# _strptime           distributed         pickle              typed_ast
# _struct             distutils           pickleshare         types
# _symtable           doctest             pickletools         typing
# _system_path        docutils            pip                 typing_extensions
# _testbuffer         dummy_threading     pipes               ujson
# _testcapi           email               pkg_resources       unicodecsv
# _testconsole        encodings           pkginfo             unicodedata
# _testimportmultiple ensurepip           pkgutil             unittest
# _testinternalcapi   entrypoints         platform            urllib
# _testmultiphase     enum                plistlib            urllib3
# _thread             erfa                pluggy              uu
# _threading_local    errno               ply                 uuid
# _tkinter            et_xmlfile          poplib              venv
# _tracemalloc        fastcache           posixpath           warnings
# _warnings           faulthandler        pprint              watchdog
# _weakref            filecmp             profile             wave
# _weakrefset         fileinput           prometheus_client   wcwidth
# _win32sysloader     filelock            prompt_toolkit      weakref
# _winapi             flake8              pstats              webbrowser
# _winxptheme         flask               psutil              webencodings
# _xxsubinterpreters  fnmatch             pty                 werkzeug
# _yaml               folium              ptyprocess          wheel
# abc                 formatter           pvectorc            widgetsnbextension
# adodbapi            fractions           py                  win2kras
# afxres              fsspec              py_compile          win32api
# aifc                ftplib              pyclbr              win32clipboard
# alabaster           functools           pycodestyle         win32com
# anaconda_navigator  future              pycosat             win32con
# anaconda_project    gc                  pycparser           win32console
# antigravity         genericpath         pycurl              win32cred
# anyio               geographiclib       pydoc               win32crypt
# appdirs             geopy               pydoc_data          win32cryptcon
# argh                getopt              pydocstyle          win32ctypes
# argon2              getpass             pyexpat             win32event
# argparse            gettext             pyflakes            win32evtlog
# array               gevent              pygments            win32evtlogutil
# asn1crypto          glob                pylab               win32file
# ast                 glob2               pylint              win32gui
# astroid             greenlet            pyls                win32gui_struct
# astropy             gzip                pyls_black          win32help
# async_generator     h5py                pyls_jsonrpc        win32inet
# asynchat            hashlib             pyls_spyder         win32inetcon
# asyncio             heapdict            pyodbc              win32job
# asyncore            heapq               pyparsing           win32lz
# atexit              hmac                pyreadline          win32net
# atomicwrites        html                pyrsistent          win32netcon
# attr                html5lib            pytest              win32pdh
# audioop             http                pythoncom           win32pdhquery
# autopep8            idlelib             pytz                win32pdhutil
# autoreload          idna                pywin               win32pipe
# babel               imagecodecs         pywin32_bootstrap   win32print
# backcall            imageio             pywin32_testutil    win32process
# backports           imagesize           pywintypes          win32profile
# base64              imaplib             pywt                win32ras
# bcrypt              imghdr              pyximport           win32rcparser
# bdb                 imp                 qdarkstyle          win32security
# binascii            importlib           qtawesome           win32service
# binhex              importlib_metadata  qtconsole           win32serviceutil
# binstar_client      iniconfig           qtpy                win32timezone
# bisect              inspect             queue               win32trace
# bitarray            intervaltree        quopri              win32traceutil
# bkcharts            io                  random              win32transaction
# black               ipaddress           rasutil             win32ts
# blackd              ipykernel           re                  win32ui
# bleach              ipykernel_launcher  readline            win32uiole
# blib2to3            ipython_genutils    regcheck            win32verstamp
# bokeh               ipywidgets          regex               win32wnet
# boto                isapi               regutil             win_inet_pton
# bottleneck          isort               repo_cli            win_unicode_console
# brain_argparse      isympy              reprlib             wincertstore
# brain_attrs         itertools           requests            winerror
# brain_boto3         itsdangerous        rlcompleter         winioctlcon
# brain_builtin_inference jdcal               rmagic              winnt
# brain_collections   jedi                rope                winperf
# brain_crypt         jinja2              rtree               winpty
# brain_curses        joblib              ruamel_yaml         winreg
# brain_dataclasses   json                run                 winsound
# brain_dateutil      json5               runpy               winxpgui
# brain_fstrings      jsonschema          sched               winxptheme
# brain_functools     jupyter             schedule            wrapt
# brain_gi            jupyter_client      scipy               wsgiref
# brain_hashlib       jupyter_console     scripts             xdrlib
# brain_http          jupyter_core        seaborn             xlrd
# brain_hypothesis    jupyter_packaging   secrets             xlsxwriter
# brain_io            jupyter_server      select              xlwings
# brain_mechanize     jupyterlab          selectors           xlwt
# brain_multiprocessing jupyterlab_pygments send2trash          xml
# brain_namedtuple_enum jupyterlab_server   servicemanager      xmlrpc
# brain_nose          jupyterlab_widgets  setuptools          xmltodict
# brain_numpy_core_fromnumeric keyring             shelve              xxsubtype
# brain_numpy_core_function_base keyword             shlex               yaml
# brain_numpy_core_multiarray kiwisolver          shutil              yapf
# brain_numpy_core_numeric lazy_object_proxy   signal              yapftests
# brain_numpy_core_numerictypes lib2to3             simplegeneric       zict
# brain_numpy_core_umath libarchive          singledispatch      zipapp
# brain_numpy_ndarray libfuturize         sip                 zipfile
# brain_numpy_random_mtrand libpasteurize       sipconfig           zipimport
# brain_numpy_utils   lief                sipdistutils        zipp
# brain_pkg_resources linecache           site                zlib
# brain_pytest        llvmlite            six                 zmq
# brain_qt            locale              skimage             zope
# brain_random        locket              sklearn
# brain_re            logging             smtpd
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".

# %%
import messages as msg

msg.hello()
msg.bye()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-903fe05af100> in <module>
# ----> 1 import messages as msg
#       2
#       3 msg.hello()
#       4 msg.bye()
#
# ModuleNotFoundError: No module named 'messages'
