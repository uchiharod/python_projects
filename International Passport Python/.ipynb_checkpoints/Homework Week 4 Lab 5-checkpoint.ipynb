# %%
##Homework Week 4 Lab 5 modifying a value in the list and updating it

##*5

#1

dogs = ["German Shephard", "Rot Wiler", "Bull Mastiff", "Pitbull," "Alsation"]

dogs [3] = "Dalmation"

print(dogs [3])

#2

dogs = ["German Shephard", "Rot Wiler" , "Bull Mastiff", "Pitbull" , "Alsation"]

dogs [3] = "Dalmation"

print(dogs)

#3

hoe_names = ["Kelly", "Brittney", "Lakiesha", "Shaniqua", "Makeda"]

hoe_names [0] = "Kiesha"

print(hoe_names [0])

print(str(hoe_names) + "\nare the biggest 304 names in the business")

#4

hoe_names = ["Kelly", "Brittney", "Lakiesha", "Shaniqua", "Makeda"]

hoe_names [3] = "Kiesha"

print(hoe_names)

print("Are the biggest hoes")

#5

colours = ["Blue", "Yellow", "Green", "Purple", "Orange", "Pink"]

colours [1] = "Turquoise"

print(colours)

print("The list has been fully modified! ")
# Out:
# Dalmation
# ['German Shephard', 'Rot Wiler', 'Bull Mastiff', 'Dalmation', 'Alsation']
# Kiesha
# ['Kiesha', 'Brittney', 'Lakiesha', 'Shaniqua', 'Makeda']
# are the biggest 304 names in the business
# ['Kelly', 'Brittney', 'Lakiesha', 'Kiesha', 'Makeda']
# Are the biggest hoes
# ['Blue', 'Turquoise', 'Green', 'Purple', 'Orange', 'Pink']
# The list has been fully modified!

# %%
##Homework Week 4 Lab 5 modifying a value in the list and updating it

##*5

#1

dogs = ["German Shephard", "Rot Wiler", "Bull Mastiff", "Pitbull," "Alsation"]

dogs [3] = "Dalmation"

print(dogs [3])

#2

dogs = ["German Shephard", "Rot Wiler" , "Bull Mastiff", "Pitbull" , "Alsation"]

dogs [3] = "Dalmation"

print(dogs)

#3

friend_names = ["Steve", "Steph", "Tony", "Josh", "Maki"]

friend_names[0] = "Tommy"

print(friend_names[0])

print(str(friend_names) + "are my peeps.")

#4

friend_names = ["Steve", "Steph", "Tony", "Josh", "Maki"]

friend_names[0] = "Goemon"

print(friend_names)

print(str(friend_names) + " Are the best friends of mine.")

#5

colours = ["Blue", "Yellow", "Green", "Purple", "Orange", "Pink"]

colours [1] = "Turquoise"

print(colours)

print("The list has been fully modified! ")
# Out:
# Dalmation
# ['German Shephard', 'Rot Wiler', 'Bull Mastiff', 'Dalmation', 'Alsation']
# Tommy
# ['Tommy', 'Steph', 'Tony', 'Josh', 'Maki']are my peeps.
# ['Goemon', 'Steph', 'Tony', 'Josh', 'Maki']
# ['Goemon', 'Steph', 'Tony', 'Josh', 'Maki'] Are the best friends of mine.
# ['Blue', 'Turquoise', 'Green', 'Purple', 'Orange', 'Pink']
# The list has been fully modified!
