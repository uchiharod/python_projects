# %%
##Homework Week 4 Lab 3 Selecting multiple elements from our list

##*5

#1

print("Enter your favourite trainers: ")

creps = input("Name here: ")

print(creps + " Are your favourite trainers")

print("Take a look at the following list")

creps1 = ["Nike", "Adidas", "Gola" , "Diadora" , "Puma"]

creps2 = ["Treds", "Asos", "Catepillar"]

print(creps1)

print(creps + " is on the list but the best are ")

print (creps1 [3:] + creps2 [0:])

#2

list = ["Mario Jart" , "Street Fighter", "Resident Evil", "Halo", "FIFA Soccer"]

print(list [2:])

#3

hoes = ["Kiesha", "Brittney Renner", "Lakiesha", "Zaniqua", "Makiesha"]

hoes1 = ["Debbie", "Kelly", "Stacey", "Sharon", "Karon", "Tracey"]

print(hoes [2:] + hoes1 [2:])

#4

hoes = ["Janet", "Chole", "Ella", "Bella"]

print(hoes [1:])

print ("Are all 304's ")

#5

tv_shows = ["Dallas", "One Tree Hil", "Rossane", "Fraser", "Everybody hates chris"]

print(tv_shows [2:])
# Out:
# Enter your favourite trainers:
# Name here: Rod
# Rod Are your favourite trainers
# Take a look at the following list
# ['Nike', 'Adidas', 'Gola', 'Diadora', 'Puma']
# Rod is on the list but the best are
# ['Diadora', 'Puma', 'Treds', 'Asos', 'Catepillar']
# ['Resident Evil', 'Halo', 'FIFA Soccer']
# ['Lakiesha', 'Zaniqua', 'Makiesha', 'Stacey', 'Sharon', 'Karon', 'Tracey']
# ['Chole', 'Ella', 'Bella']
# Are all 304's
# ['Rossane', 'Fraser', 'Everybody hates chris']

# %%
##Homework Week 4 Lab 3 Selecting multiple elements from our list

##*5

#1

print("Enter your favourite shoes: ")

shoes = input("Name here: ")

print(shoes + " are your favourite shoes.")

print("Take a look at the following list of shoes")

shoes1 = ["Nike", "Adidas", "Gola" , "Diadora" , "Puma"]

shoes2 = ["Dooda", "Reebok", "Bomba"]

print(shoes1)

print(str(shoes1) + " is on the list but the best are ")

print (shoes1 [3:] + shoes2 [0:])

#2

list = ["Mario Kart" , "Street Fighter", "Resident Evil", "Halo", "FIFA Soccer"]

print(list [2:])

#3

hoes = ["Kiesha", "Brittney Renner", "Lakiesha", "Zaniqua", "Makiesha"]

hoes1 = ["Debbie", "Kelly", "Stacey", "Sharon", "Karon", "Tracey"]

print(hoes [2:] + hoes1 [2:])

#4

hoes = ["Janet", "Chole", "Ella", "Bella"]

print(hoes [1:])

print ("Are all 304's ")

#5

tv_shows = ["Dallas", "One Tree Hil", "Rossane", "Fraser", "Everybody hates chris"]

print(tv_shows [2:])
# Out:
# Enter your favourite shoes:
# Name here: Rod
# Rod are your favourite shoes.
# Take a look at the following list of shoes
# ['Nike', 'Adidas', 'Gola', 'Diadora', 'Puma']
# ['Nike', 'Adidas', 'Gola', 'Diadora', 'Puma'] is on the list but the best are
# ['Diadora', 'Puma', 'Dooda', 'Reebok', 'Bomba']
# ['Resident Evil', 'Halo', 'FIFA Soccer']
# ['Lakiesha', 'Zaniqua', 'Makiesha', 'Stacey', 'Sharon', 'Karon', 'Tracey']
# ['Chole', 'Ella', 'Bella']
# Are all 304's
# ['Rossane', 'Fraser', 'Everybody hates chris']
