# %%
##Homework Week 3 Lab 6 complex input function example 10/03/2024 Submission date 16/03/2024

##*5

#1

print("Answer all the questions please: ")

first_name = input("What is your first name? ")

last_name = input("What is your surname? ")

email = input("What is your email? ")

home_address = input("What is your home address? ")

print("Before proceeding to the next stage please review and confirm information below: ")

print("Your First Name: " + first_name)

print("Your Surname: " + last_name)

print("Your Email: " + email)

print("Your Home Address: " + home_address)

#2

print("Fill out the following questions please: ")

name = input("What is your name?")

age = input("What is your age?")

apartment_number = input("What is your apartment number?")

email = input("What is your email? ")

print("Please review the following before proceeding: ")

print("Your name is " + name)

print("You are " + age + " Years old" )

print("Your apartment number is " + apartment_number)

print("Your email is " + email)

#3

print("PLEASE FILL OUT THE FOLLOWING: ")

print("Your name:")

name = input()

print("Your age: ")

age = input()

print("Your Home address: ")

home_address = input()

print("Your Email address: ")

email = input()

print("PLEASE REVIEW THE FOLLOWING: ")

print("Your name is: " + name)

print("You are: " + age + " Years old ")

print("Your Home address is: " + home_address)

print("Your Email address is: " + email)

#4

print("FILL OUT THE FOLLOWING: ")

n1 = input("Apartment Door Number: ")

name = input("Your Name: ")

address = input("Your Address: ")

email = input("Email Address: ")

print("PLEASE REVIEW THE FOLLOWING BEFORE CONTINUING: ")

result = "Apartment number: " + (n1) + " Your Name Is: " + (name) + " Address Is: " + (address) + " Email is: " + (email)

print(result)

#5

print("FILLOUT FORM PLEASE BEFORE PROGRESSING")

fname = input("ENTER FIRST NAME: ")

lname = input("ENTER SURNAME: ")

ni_number = input("ENTER NATIONAL INSURANCE NUMBER:")

print("ENTER ADDRESS: ")

address = input()

tele_nu = input("TELEPHONE NUMBER: ")

print("PLEASE REVIEW THE FOLLOWING BEFORE PROCEEDING")

print("Your First Name is: " + fname)

print("Your Surname is: " + lname)

print("Your NI Number is: " + ni_number)

print("Your Address is: " + address)

print("Your Telephone Number is: " + tele_nu)
# Out:
# Answer all the questions please:
# What is your first name? Rod
# What is your surname? Moore
# What is your email? demetri@hotmail.com
# What is your home address? 887 Doody Drive
# Before proceeding to the next stage please review and confirm information below:
# Your First Name: Rod
# Your Surname: Moore
# Your Email: demetri@hotmail.com
# Your Home Address: 887 Doody Drive
# Fill out the following questions please:
# What is your name?ROd
# What is your age?45
# What is your apartment number?345
# What is your email? dooky@spaceman.com
# Please review the following before proceeding:
# Your name is ROd
# You are 45 Years old
# Your apartment number is 345
# Your email is dooky@spaceman.com
# PLEASE FILL OUT THE FOLLOWING:
# Your name:
# Daria
# Your age:
# 33
# Your Home address:
# 987 Cammy Drive
# Your Email address:
# cammy@hotmal.com
# PLEASE REVIEW THE FOLLOWING:
# Your name is: Daria
# You are: 33 Years old
# Your Home address is: 987 Cammy Drive
# ...
