# %%
##Homework Week 3 Lab 4 building a calculator using the input function to add two decimal numbers together using the float function 10/03/2024 Submission date 16/03/2024

##*5

#1

n1 = input("Enter first number here: ")

n2 = input("Enter second number here: ")

sum = float(n1) + float(n2)

print(sum)

#2

number1 = input("First number: ")

number2 = input("Second number: ")

result = float(number1) + float(number2)

print("The answer is " + str(result))

#3

n1 = input("First number here: ")

n2 = input("Second number here: ")

name = input("Enter Name Here:")

together = float(n1) + float(n2)

print("Thanks " + name + " Your answer is " + str(together))

#4

n1 = input("Please enter first number: ")

n2 = input("Please enter second number: ")

result = float(n1) + float(n2)

age = (32)

print("Sorry Kiesha, you are not " + str(result) + " You are " + str(age) + " Which is to old ")

#5

n1 = input("First Number Here: ")

n2 = input("Second Number Here: ")

result = float(n1) * float(n2)

print(result)
# Out:
# Enter first number here: 45
# Enter second number here: 45
# 90.0
# First number: 45
# Second number: 45
# The answer is 90.0
# First number here: 45
# Second number here: 45
# Enter Name Here:45
# Thanks 45 Your answer is 90.0
# Please enter first number: 45
# Please enter second number: 45
# Sorry Kiesha, you are not 90.0 You are 32 Which is to old

# %%
##Homework Week 3 Lab 4 building a calculator using the input function to add two decimal numbers together using the float function 10/03/2024 Submission date 16/03/2024

##*5

#1

n1 = input("Enter first number here: ")

n2 = input("Enter second number here: ")

sum = float(n1) + float(n2)

print(sum)

#2

new_number1 = input("First number: ")

new_number2 = input("Second number: ")

new_result = float(new_number1) + float(new_number2)

print("The answer is " + str(new_result))

#3

n3 = input("First number here: ")

n4 = input("Second number here: ")

name = input("What's your name fool? ")

result_n3n4 = float(n3) + float(n4)

print("Hey " + name + " The answer is " + str(result_n3n4))

#4

n5 = input("Please enter first number: ")

n6 = input("Please enter second number: ")

result_n5n6 = float(n5) + float(n6)

print("Total is " + str(result_n5n6))

#5

n7 = input("First Number Here: ")

n8 = input("Second Number Here: ")

result_n7n8 = float(n7) * float(n8)

print(result_n7n8)
# Out:
# Enter first number here: 55
# Enter second number here: 55
# 110.0
# First number: 55
# Second number: 55
# The answer is 110.0
# First number here: 55
# Second number here: 55
# What's your name fool? Rod
# Hey Rod The answer is 110.0
# Please enter first number: 66
# Please enter second number: 66
# Total is 132.0
# First Number Here: 66
# Second Number Here: 66
# 4356.0
