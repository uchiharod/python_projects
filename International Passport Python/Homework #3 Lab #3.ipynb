# %%
##Homework Week 3 Lab 3 building a calculator using the input function to add two whole numbers together using the int function 10/03/2024 Submission date 16/03/2024

##*5

#1

first_number = input("enter the first number:")

second_number = input("Enter the second number:")

result = int(first_number) + int(second_number)

result_1 = (str(first_number) + " + " + str (second_number) + " = ")

print(str(result_1) + str(result))

#2

first_number = input("Enter first number: ")

second_number = input("Enter second number: ")

result = int(first_number) // int(second_number) #Double slash for Integer division

print(result)

#3

number1 = input("Enter first number: ")

number2 = input("Enter second number: ")

result = int(number1) / int(number2) #Single slash for Float division

print(result)

#4

n1 = input("First number: ")

n2 = input("Second number: ")

result = int(n1) * int(n2)

print(result)

#5

n1 = input("Your first number please: ")

n2 = input("Your second number please: ")

result = int(n1) - int(n2)

print(result)
# Out:
# enter the first number:56
# Enter the second number:65
# 56 + 65 = 121
# Enter first number: 33
# Enter second number: 44
# 0
# Enter first number: 44
# Enter second number: 44
# 1.0
# First number: 56
# Second number: 5
# 280
# Your first number please: 55
# Your second number please: 55
# 0

# %%
##Homework Week 3 Lab 3 building a calculator using the input function to add two whole numbers together using the int function 10/03/2024 Submission date 16/03/2024

##

#1

first_number = input("Enter the first number:")

second_number = input("Enter the second number:")

total = int(first_number) + int(second_number)

total_strings = (str(first_number) + " + " + str (second_number) + " = ")

print(str(total_strings) + str(total))

#2

first_number = input("Enter first number to divide: ")

second_number = input("Enter second number to divide: ")

result = int(first_number) // int(second_number) #Double slash for Integer division

print(float(result))

#3

number1 = input("Enter first number: ")

number2 = input("Enter second number: ")

result = int(number1) / int(number2) #Single slash for Float division

print(result)

#4

n1 = input("First number: ")

n2 = input("Second number: ")

result = int(n1) * int(n2)

print(result)

#5

n1 = input("Your first number please: ")

n2 = input("Your second number please: ")

result = int(n1) - int(n2)

print(str(n1) + " - " + str(n2) + " = " + str(result))
# Out:
# Enter the first number:44
# Enter the second number:4
# 44 + 4 = 48
# Enter first number to divide: 44
# Enter second number to divide: 4
# 11.0
# Enter first number: 44
# Enter second number: 4
# 11.0
# First number: 44
# Second number: 4
# 176
# Your first number please: 44
# Your second number please: 4
# 44 - 4 = 40
